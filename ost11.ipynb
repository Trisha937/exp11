# %% [markdown]
# <a href="https://colab.research.google.com/github/Trisha937/exp11/blob/main/ost11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sample Analysis Plot")
plt.show()
